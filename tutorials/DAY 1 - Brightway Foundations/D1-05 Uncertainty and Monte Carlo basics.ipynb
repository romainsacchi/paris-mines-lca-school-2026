# %% [markdown]
# # D1-05 Uncertainty and Monte Carlo basics
#
# This notebook introduces a practitioner-facing uncertainty workflow in `brightway` using the uncertainty information already present in the imported BAFU database.
#
# We move from exchange-level uncertainty, to the `stats_arrays` data model, to stochastic LCIA scores and ranking robustness.

# %% [markdown]
# ## Learning goals
#
# - Find uncertainty information attached to exchanges in a real database.
# - Connect Brightway exchange fields to the `stats_arrays` parameter-array format.
# - Sample and visualize the uncertainty of a few individual exchanges.
# - Run stochastic LCAs with `brightway` and summarize score distributions.
# - Discuss how percentile overlap and a statistical test inform ranking robustness.
# - Use a Sobol-style variance decomposition to identify dominant uncertainty drivers in a reduced model.
# - Inject precomputed samples for selected exchanges while leaving the rest of the model stochastic.

# %% [markdown]
# ## Background references
#
# - Mutel, C. (2017). *Brightway: An open source framework for life cycle assessment*. Journal of Open Source Software, 2(12), 236. https://doi.org/10.21105/joss.00236
# - `stats_arrays` documentation: https://stats-arrays.readthedocs.io/en/latest/

# %% [markdown]
# ## 1) Load the imported BAFU database and choose two comparison activities
#
# To stay close to `D1-04`, we compare two passenger-car operation activities already present in the BAFU workbook: one petrol car and one natural-gas car.
#
# The impact category is climate change (`EF v3.1`, `GWP100`).

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import display
from prettytable import PrettyTable
from scipy import stats
from stats_arrays import MCRandomNumberGenerator, UncertaintyBase, uncertainty_choices

import bw2calc as bc
import bw2data as bd
import bw_processing as bwp

pd.options.display.float_format = '{:,.3f}'.format
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   __import__('pkg_resources').declare_namespace(__name__)

# %%
bd.projects.set_current('paris-lca-course-2026')
database_name = 'bafu'
method = ('EF v3.1', 'climate change', 'global warming potential (GWP100)')

# %%
petrol_car = [
    act for act in bd.Database("bafu")
    if all(
        x in act["name"].lower() for x in ("gasoline", "passenger car", "medium")
    )
    and act["unit"] == "kilometer"
    and act["location"] == "RER"
    and "fleet" not in act["name"]
][0]

ng_car = [
    act for act in bd.Database("bafu")
    if all(
        x in act["name"].lower() for x in ("compressed gas", "passenger car", "medium")
    )
    and act["unit"] == "kilometer"
    and act["location"] == "RER"
    and "fleet" not in act["name"]
    and "biomethane" not in act["name"]
][0]

# %%
[
    act for act in bd.Database("bafu")
    if all(
        x in act["name"].lower() for x in ("compressed gas", "passenger car", )
    )
    and act["unit"] == "kilometer"
    and act["location"] == "RER"
    and "fleet" not in act["name"]
    and "biomethane" not in act["name"]
]
# Out:
# ['Transport, passenger car, compressed gas, Compact, 2019, EURO-6d-TEMP' (kilometer, RER, None),
#  'Transport, passenger car, compressed gas, Medium, 2016, EURO-6ab' (kilometer, RER, None),
#  'Transport, passenger car, compressed gas, Large, 2021, EURO-6d' (kilometer, RER, None),
#  'Transport, passenger car, compressed gas, Medium, 2013, EURO-5' (kilometer, RER, None),
#  'Transport, passenger car, compressed gas, Large, 2013, EURO-5' (kilometer, RER, None),
#  'Transport, passenger car, compressed gas, Large, 2019, EURO-6d-TEMP' (kilometer, RER, None),
#  'Transport, passenger car, compressed gas, Medium, 2021, EURO-6d' (kilometer, RER, None),
#  'Transport, passenger car, compressed gas, Large, 2008, EURO-4' (kilometer, RER, None),
#  'Transport, passenger car, compressed gas, Large, 2016, EURO-6ab' (kilometer, RER, None),
#  'Transport, passenger car, compressed gas, Medium, 2008, EURO-4' (kilometer, RER, None),
#  'Transport, passenger car, compressed gas, Medium, 2003, EURO-3' (kilometer, RER, None),
#  'Transport, passenger car, compressed gas, Compact, 2013, EURO-5' (kilometer, RER, None),
#  'Transport, passenger car, compressed gas, Large SUV, 2016, EURO-6ab' (kilometer, RER, None),
#  'Transport, passenger car, compressed gas, Large SUV, 2019, EURO-6d-TEMP' (kilometer, RER, None),
#  'Transport, passenger car, compressed gas, Compact, 2008, EURO-4' (kilometer, RER, None),
#  'Transport, passenger car, compressed gas, Large SUV, 2013, EURO-5' (kilometer, RER, None),
#  'Transport, passenger car, compressed gas, Large SUV, 2008, EURO-4' (kilometer, RER, None),
#  'Transport, passenger car, compressed gas, Medium, 2018, EURO-6c' (kilometer, RER, None),
#  'Transport, passenger car, compressed gas, Medium, 2019, EURO-6d-TEMP' (kilometer, RER, None),
#  'Transport, passenger car, compressed gas, Large, 2018, EURO-6c' (kilometer, RER, None),
#  'Transport, passenger car, compressed gas, Compact, 2016, EURO-6ab' (kilometer, RER, None),
#  'Transport, passenger car, compressed gas, Compact, 2003, EURO-3' (kilometer, RER, None),
#  'Transport, passenger car, compressed gas, Compact, 2018, EURO-6c' (kilometer, RER, None),
#  'Transport, passenger car, compressed gas, Large SUV, 2003, EURO-3' (kilometer, RER, None),
#  'Transport, passenger car, compressed gas, Compact, 2021, EURO-6d' (kilometer, RER, None),
#  'Transport, passenger car, compressed gas, Large SUV, 2018, EURO-6c' (kilometer, RER, None),
#  'Transport, passenger car, compressed gas, Large, 2003, EURO-3' (kilometer, RER, None),
#  'Transport, passenger car, compressed gas, Large SUV, 2021, EURO-6d' (kilometer, RER, None)]

# %%
petrol_car
# Out:
# 'Transport, passenger car, gasoline hybrid, Medium, 2013, EURO-5' (kilometer, RER, None)

# %%
ng_car
# Out:
# 'Transport, passenger car, compressed gas, Medium, 2003, EURO-3' (kilometer, RER, None)

# %% [markdown]
# ## 2) Inspect exchange uncertainty and the `stats_arrays` data model
#
# Brightway stores uncertainty directly on exchanges, using fields such as `uncertainty type`, `loc`, `scale`, `minimum`, and `maximum`.
#
# These fields follow the [`stats_arrays`](https://stats-arrays.readthedocs.io/en/latest/) convention.
#
# | Name                      | ID | loc          | scale       | shape | minimum            | maximum            |
# | ------------------------- | -: | ------------ | ----------- | ----- | ------------------ | ------------------ |
# | Undefined                 |  0 | static value |             |       |                    |                    |
# | No uncertainty            |  1 | static value |             |       |                    |                    |
# | Lognormal                 |  2 | mu           | sigma       |       | lower bound (opt.) | upper bound (opt.) |
# | Normal                    |  3 | mu           | sigma       |       | lower bound (opt.) | upper bound (opt.) |
# | Uniform                   |  4 |              |             |       | minimum            | maximum            |
# | Triangular                |  5 | mode         |             |       | minimum            | maximum            |
# | Bernoulli                 |  6 | p            |             |       | lower bound (opt.) | upper bound (opt.) |
# | Discrete uniform          |  7 |              |             |       | minimum            | maximum            |
# | Weibull                   |  8 | offset       | lambda      | k     |                    |                    |
# | Gamma                     |  9 | offset       | theta       | k     |                    |                    |
# | Beta                      | 10 | alpha        | upper bound | beta  |                    |                    |
# | Generalized extreme value | 11 | mu           | sigma       | xi    |                    |                    |
# | Student's t               | 12 | median       | scale       | nu    |                    |                    |

# %%
def pretty_number(value):
    if value is None or pd.isna(value):
        return None
    value = float(value)
    if value == 0:
        return '0'
    if abs(value) < 1e-3 or abs(value) >= 1e4:
        return f'{value:.3e}'
    return f'{value:.3f}'.rstrip('0').rstrip('.')


def uncertainty_name(uncertainty_type):
    cls = uncertainty_choices[int(uncertainty_type)]
    return cls.__name__.replace('Uncertainty', '')

# %%
print('First uncertain technosphere exchanges in the petrol car activity:')
rows = []
for exc in petrol_car.technosphere():
    data = exc.as_dict()
    uncertainty_type = data.get('uncertainty type')
    if uncertainty_type in (None, 0):
        continue
    rows.append({
        'input': exc.input['name'],
        'exchange type': data.get('type'),
        'amount': pretty_number(data.get('amount')),
        'distribution': uncertainty_name(uncertainty_type),
        'uncertainty type': int(uncertainty_type),
        'loc': pretty_number(data.get('loc')),
        'scale': pretty_number(data.get('scale')),
        'minimum': pretty_number(data.get('minimum')),
        'maximum': pretty_number(data.get('maximum')),
    })
pd.DataFrame(rows).head(10)
# Out:
# First uncertain technosphere exchanges in the petrol car activity:
#                                                input exchange type     amount  \
# 0                Brake wear emissions, passenger car  technosphere  8.380e-06
# 1                                     Disposal, road  technosphere  9.000e-04
# 2                  Fuel supply for gasoline vehicles  technosphere      0.048
# 3                         Maintenance, passenger car  technosphere  7.920e-06
# 4                       Operation, maintenance, road  technosphere      0.001
# 5  Passenger car, gasoline hybrid, Medium, 2013, ...  technosphere  5.000e-06
# 6                        Refrigerant R134a, at plant  technosphere  8.020e-06
# 7                                               Road  technosphere  8.660e-04
# 8                 Road wear emissions, passenger car  technosphere  1.610e-05
# 9  Transport, freight, lorry, 16t-32t gross weigh...  technosphere  8.020e-07
#
#   distribution  uncertainty type      loc  scale minimum maximum
# 0    Lognormal                 2   -11.69  0.242    None    None
# 1    Lognormal                 2   -7.013  0.208    None    None
# 2    Lognormal                 2    -3.03  0.016    None    None
# 3    Lognormal                 2  -11.746  0.061    None    None
# 4    Lognormal                 2   -6.653  0.208    None    None
# 5    Lognormal                 2  -12.206  0.061    None    None
# 6    Lognormal                 2  -11.734  0.224    None    None
# 7    Lognormal                 2   -7.052  0.208    None    None
# 8    Lognormal                 2  -11.037  0.242    None    None
# 9    Lognormal                 2  -14.036  0.189    None    None

# %%
print('First uncertain exchanges in the natural gas car activity:')
rows = []
for exc in petrol_car.biosphere():
    data = exc.as_dict()
    uncertainty_type = data.get('uncertainty type')
    if uncertainty_type in (None, 0):
        continue
    rows.append({
        'input': exc.input['name'],
        'exchange type': data.get('type'),
        'amount': pretty_number(data.get('amount')),
        'distribution': uncertainty_name(uncertainty_type),
        'uncertainty type': int(uncertainty_type),
        'loc': pretty_number(data.get('loc')),
        'scale': pretty_number(data.get('scale')),
        'minimum': pretty_number(data.get('minimum')),
        'maximum': pretty_number(data.get('maximum')),
    })
pd.DataFrame(rows).head(10)
# Out:
# First uncertain exchanges in the natural gas car activity:
#           input exchange type     amount distribution  uncertainty type  \
# 0     1-Pentene     biosphere  3.250e-09    Lognormal                 2
# 1     1-Pentene     biosphere  1.090e-09    Lognormal                 2
# 2     1-Pentene     biosphere  5.170e-09    Lognormal                 2
# 3  Acetaldehyde     biosphere  2.600e-08    Lognormal                 2
# 4  Acetaldehyde     biosphere  8.680e-09    Lognormal                 2
# 5  Acetaldehyde     biosphere  4.140e-08    Lognormal                 2
# 6       Acetone     biosphere  1.950e-08    Lognormal                 2
# 7       Acetone     biosphere  6.510e-09    Lognormal                 2
# 8       Acetone     biosphere  3.100e-08    Lognormal                 2
# 9      Acrolein     biosphere  6.510e-09    Lognormal                 2
#
#        loc  scale minimum maximum
# 0  -19.545  0.036    None    None
# 1  -20.637  0.036    None    None
# 2   -19.08  0.036    None    None
# 3  -17.465  0.036    None    None
# 4  -18.562  0.036    None    None
# 5      -17  0.036    None    None
# 6  -17.753  0.036    None    None
# 7   -18.85  0.036    None    None
# 8  -17.289  0.036    None    None
# 9   -18.85  0.036    None    None

# %% [markdown]
# ## 3) Sample a few exchange distributions directly
#
# Before running full Monte Carlo LCAs, it is useful to look at the uncertainty of a few individual exchanges.
#
# Here we stay at the exchange level and let `stats_arrays` sample three uncertain biosphere exchanges from the petrol car activity.

# %%
def pick_unique_uncertain_exchanges(activity, n=3):
    selected = []
    seen = set()
    for exc in activity.biosphere():
        data = exc.as_dict()
        if data.get('uncertainty type') in (None, 0):
            continue
        name = exc.input['name']
        if name in seen:
            continue
        seen.add(name)
        selected.append(exc)
        if len(selected) == n:
            break
    return selected


selected_exchanges = pick_unique_uncertain_exchanges(petrol_car, n=3)
selected_labels = [exc.input['name'] for exc in selected_exchanges]
selected_amounts = [exc.as_dict().get('amount') for exc in selected_exchanges]
selected_params = UncertaintyBase.from_dicts(*(exc.as_dict() for exc in selected_exchanges))

selected_table = pd.DataFrame.from_records(selected_params)
selected_table.insert(0, 'exchange', selected_labels)
selected_table.insert(1, 'amount', [pretty_number(x) for x in selected_amounts])
selected_table['distribution'] = selected_table['uncertainty_type'].map(lambda x: uncertainty_name(int(x)))
for column in ['loc', 'scale', 'shape', 'minimum', 'maximum']:
    selected_table[column] = selected_table[column].map(pretty_number)
display(selected_table[['exchange', 'amount', 'distribution', 'uncertainty_type', 'loc', 'scale', 'minimum', 'maximum']])
# Out:
#        exchange     amount distribution  uncertainty_type      loc  scale  \
# 0     1-Pentene  3.250e-09    Lognormal                 2  -19.545  0.036
# 1  Acetaldehyde  2.600e-08    Lognormal                 2  -17.465  0.036
# 2       Acetone  1.950e-08    Lognormal                 2  -17.753  0.036
#
#   minimum maximum
# 0    None    None
# 1    None    None
# 2    None    None

# %%
selected_params
# Out:
# array([(-19.54461084, 0.03623573, nan, nan, nan, False, 2),
#        (-17.4651693 , 0.03623573, nan, nan, nan, False, 2),
#        (-17.75285137, 0.03623573, nan, nan, nan, False, 2)],
#       dtype=[('loc', '<f8'), ('scale', '<f8'), ('shape', '<f8'), ('minimum', '<f8'), ('maximum', '<f8'), ('negative', '?'), ('uncertainty_type', 'u1')])

# %%
draws = 2000
rng = MCRandomNumberGenerator(selected_params)
samples = np.vstack([rng.next() for _ in range(draws)])

fig, axes = plt.subplots(1, len(selected_labels), figsize=(12, 3.5))
axes = np.atleast_1d(axes)

for idx, ax in enumerate(axes):
    ax.hist(samples[:, idx], bins=40, color='#4C78A8', alpha=0.8)
    ax.axvline(selected_amounts[idx], color='#F58518', linestyle='--', linewidth=2)
    ax.set_title(selected_labels[idx])
    ax.set_xlabel('Sampled amount')
    ax.set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4) Run stochastic LCAs in Brightway
#
# Now we propagate uncertainty through the full inventory and impact assessment calculation.
#
# `bw2calc.LCA` does stochastic LCA when `bc.LCA(..., use_distributions=True)` and repeated calls to `next(lca)`.
#
# We also fix the random seed so everyone in the course sees the same Monte Carlo sequence.

# %%
def stochastic_scores(fu, method, iterations=300, seed=1234):
    lca = bc.LCA(
        fu,
        method=method,
        use_distributions=True,
        seed_override=seed,
    )
    lca.lci()
    lca.lcia()

    scores = [lca.score]
    for _ in range(iterations - 1):
        next(lca)
        scores.append(lca.score)

    return np.array(scores, dtype=float)

# %%
iterations = 300
seed = 1234

petrol_scores = stochastic_scores({petrol_car: 1}, method, iterations=iterations, seed=seed)
gas_scores = stochastic_scores({ng_car: 1}, method, iterations=iterations, seed=seed)

summary = pd.DataFrame([
    {
        'activity': 'Petrol car',
        'mean': petrol_scores.mean(),
        'std': petrol_scores.std(ddof=1),
        'p05': np.percentile(petrol_scores, 5),
        'p50': np.percentile(petrol_scores, 50),
        'p95': np.percentile(petrol_scores, 95),
    },
    {
        'activity': 'Natural gas car',
        'mean': gas_scores.mean(),
        'std': gas_scores.std(ddof=1),
        'p05': np.percentile(gas_scores, 5),
        'p50': np.percentile(gas_scores, 50),
        'p95': np.percentile(gas_scores, 95),
    },
])

print(f'Random seed used: {seed}')
display(summary)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.42e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.04e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.17e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.22e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.97e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.09e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.18e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.74e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.01e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.10e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.20e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.53e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.31e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.96e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 6.07e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.05e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.80e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.06e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 5.65e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.41e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 7.75e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.19e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.15e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.31e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.30e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 4.09e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 5.28e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.75e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 4.31e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 8.32e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.92e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.40e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.23e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.14e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.12e+13)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.15e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.43e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.28e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 6.27e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.69e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.02e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.96e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.44e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.16e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.77e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.39e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.67e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.48e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.98e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 7.55e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.89e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 8.53e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.92e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.30e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.07e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.13e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.38e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.21e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.35e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 4.12e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.73e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.46e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 4.16e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.56e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.27e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.64e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.33e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.34e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 9.50e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 7.94e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.90e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 5.73e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.76e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.81e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.67e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 4.08e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.71e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 4.17e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 5.80e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.00e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.45e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 7.00e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.44e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 5.70e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.85e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.98e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.08e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 8.83e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.71e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 5.94e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 4.45e+12)
#   warnings.warn(msg, UmfpackWarning)
# Random seed used: 1234
#           activity  mean   std   p05   p50   p95
# 0       Petrol car 0.273 0.011 0.258 0.272 0.291
# 1  Natural gas car 0.295 0.016 0.272 0.294 0.322

# %%
plt.figure(figsize=(8, 4))
plt.hist(petrol_scores, bins=30, alpha=0.6, label='Petrol car')
plt.hist(gas_scores, bins=30, alpha=0.6, label='Natural gas car')
plt.xlabel('Impact score')
plt.ylabel('Frequency')
plt.title('Monte Carlo score distributions')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5) Compare percentiles and ranking robustness
#
# A first practical check is to compare percentile ranges.
#
# For climate change, lower scores are better. So we also calculate the probability that the natural-gas car scores lower than the petrol car in a random pair of Monte Carlo draws.

# %%
interval_table = pd.DataFrame([
    {
        'activity': 'Petrol car',
        'p05': np.percentile(petrol_scores, 5),
        'p50': np.percentile(petrol_scores, 50),
        'p95': np.percentile(petrol_scores, 95),
    },
    {
        'activity': 'Natural gas car',
        'p05': np.percentile(gas_scores, 5),
        'p50': np.percentile(gas_scores, 50),
        'p95': np.percentile(gas_scores, 95),
    },
])

intervals_overlap = not (
    interval_table.loc[0, 'p95'] < interval_table.loc[1, 'p05']
    or interval_table.loc[1, 'p95'] < interval_table.loc[0, 'p05']
)
probability_gas_better = (gas_scores[:, None] < petrol_scores[None, :]).mean()

display(interval_table)
print('Do the 5th-95th percentile intervals overlap?', intervals_overlap)
print(f'Probability that natural gas scores lower than petrol: {probability_gas_better:.3f}')
# Out:
#           activity   p05   p50   p95
# 0       Petrol car 0.258 0.272 0.291
# 1  Natural gas car 0.272 0.294 0.322
# Do the 5th-95th percentile intervals overlap? True
# Probability that natural gas scores lower than petrol: 0.109

# %% [markdown]
# ## 6) Add a statistical test
#
# One possible next step is a Mann-Whitney U test.
#
# This non-parametric test checks whether the two score distributions are shifted relative to one another, without assuming normality. It should be read together with the overlap and the probability-of-superiority result above, not in isolation.

# %%
mw_result = stats.mannwhitneyu(petrol_scores, gas_scores, alternative='two-sided')

print(f'Mann-Whitney U statistic: {mw_result.statistic:,.0f}')
print(f'p-value: {mw_result.pvalue:.4f}')

if mw_result.pvalue < 0.05:
    print('The distributions are statistically shifted.')
else:
    print('The test does not show a clear shift between the distributions.')
# Out:
# Mann-Whitney U statistic: 9,798
# p-value: 0.0000
# The distributions are statistically shifted.

# %% [markdown]
# The petrol car option shows a slightly lower median impact than petrol, and the sampled distributions differ statistically; however, the uncertainty intervals overlap strongly and the probability of natural gas outperforming petrol is still above 10%, indicating limited practical confidence in the ranking.

# %% [markdown]
# ## 7) Paired stochastic LCA
#
# With possibly shared uncertain parameters, a paired comparison might be more appropriate

# %%
iterations = 300
seed = 1234

diff_scores = stochastic_scores(
    {petrol_car: 1, ng_car: -1}, # we run the delta of the two systems
    method, 
    iterations=iterations, 
    seed=seed
)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.42e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.04e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.17e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.22e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.97e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.09e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.18e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.74e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.01e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.10e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.20e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.53e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.31e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.96e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 6.07e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.05e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.80e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.06e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 5.65e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.41e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 7.75e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.19e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.15e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.31e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.30e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 4.09e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 5.28e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.75e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 4.31e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 8.32e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.92e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.40e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.23e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.14e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.12e+13)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.15e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.43e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.28e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 6.27e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.69e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.02e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.96e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.44e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.16e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.77e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.39e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.67e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.48e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.98e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 7.55e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.89e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 8.53e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.92e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.30e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.07e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.13e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.38e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.21e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.35e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 4.12e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.73e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.46e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 4.16e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.56e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.27e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.64e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.33e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.34e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 9.50e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 7.94e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.90e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 5.73e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.76e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.81e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.67e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 4.08e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.71e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 4.17e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 5.80e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.00e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.45e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 7.00e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.44e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 5.70e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.85e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.98e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.08e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 8.83e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.71e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 5.94e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 4.45e+12)
#   warnings.warn(msg, UmfpackWarning)

# %%
plt.figure(figsize=(8, 4))
plt.hist(diff_scores, bins=30, alpha=0.6, label='Petrol car vs. Natural gas car')
plt.xlabel('Impact score (<0 Petrol car, is better, >0 Natural gas is better)')
plt.ylabel('Frequency')
plt.title('Monte Carlo score distributions')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8) Bonus: a Sobol-style variance decomposition
#
# A full Sobol analysis of all uncertain Brightway exchanges would need a more elaborate parameterization workflow.
#
# Here we do something lighter and still useful: we isolate the uncertain **direct biosphere exchanges** of the petrol-car activity that have a non-zero climate-change characterization factor, and we keep all other model elements fixed.
#
# Because this reduced score model is additive and the selected inputs are sampled independently, the first-order and total-order Sobol indices are the same. In this special case, they reduce to simple variance shares.

# %%
static_lca = bc.LCA({petrol_car: 1}, method=method)
static_lca.lci()
static_lca.lcia()

petrol_index = static_lca.dicts.activity[petrol_car.id]
petrol_supply = float(static_lca.supply_array[petrol_index])

climate_relevant_exchanges = []
climate_rows = []
for exc in petrol_car.biosphere():
    data = exc.as_dict()
    if data.get('uncertainty type') in (None, 0):
        continue
    row = static_lca.dicts.biosphere[exc.input.id]
    cf = float(static_lca.characterization_matrix[row, row])
    if cf == 0:
        continue
    climate_relevant_exchanges.append(exc)
    direct_score = petrol_supply * data.get('amount') * cf
    climate_rows.append({
        'exchange': exc.input['name'],
        'amount': pretty_number(data.get('amount')),
        'CF': pretty_number(cf),
        'direct score at mean': pretty_number(direct_score),
        '_direct_score_sort': direct_score,
        'distribution': uncertainty_name(data.get('uncertainty type')),
    })

climate_exchange_table = pd.DataFrame(climate_rows)
climate_exchange_table = climate_exchange_table.sort_values('_direct_score_sort', ascending=False)
display(climate_exchange_table.drop(columns='_direct_score_sort'))
# Out:
#                      exchange     amount     CF direct score at mean  \
# 3      Carbon dioxide, fossil      0.146      1                0.146
# 10  1,1,1,2-Tetrafluoroethane  4.630e-06   1530                0.007
# 11            Methane, fossil  1.670e-06   29.8            4.977e-05
# 4         Dinitrogen monoxide  1.740e-07    273            4.750e-05
# 13            Methane, fossil  5.610e-07   29.8            1.672e-05
# 12            Methane, fossil  4.980e-07   29.8            1.484e-05
# 5         Dinitrogen monoxide  5.170e-08    273            1.411e-05
# 6         Dinitrogen monoxide  3.280e-08    273            8.954e-06
# 9                      Ethane  1.660e-07  0.437            7.254e-08
# 7                      Ethane  1.040e-07  0.437            4.545e-08
# 8                      Ethane  3.470e-08  0.437            1.516e-08
# 2                      Butane  2.690e-07  0.006            1.614e-09
# 0                      Butane  1.690e-07  0.006            1.014e-09
# 16                    Propane  3.620e-08   0.02            7.240e-10
# 14                    Propane  2.280e-08   0.02            4.560e-10
# 1                      Butane  5.640e-08  0.006            3.384e-10
# 15                    Propane  7.600e-09   0.02            1.520e-10
#
#    distribution
# 3     Lognormal
# 10    Lognormal
# 11    Lognormal
# 4     Lognormal
# 13    Lognormal
# 12    Lognormal
# 5     Lognormal
# 6     Lognormal
# 9     Lognormal
# 7     Lognormal
# 8     Lognormal
# 2     Lognormal
# 0     Lognormal
# 16    Lognormal
# 14    Lognormal
# 1     Lognormal
# 15    Lognormal

# %%
def transform_unit_cube(params, unit_cube):
    transformed = np.zeros_like(unit_cube)
    for column in range(params.shape[0]):
        distribution = uncertainty_choices[int(params['uncertainty_type'][column])]
        transformed[:, column] = distribution.ppf(
            params[column:column + 1],
            unit_cube[:, column].reshape(1, -1),
        ).reshape(-1)
    return transformed



climate_params = UncertaintyBase.from_dicts(*(exc.as_dict() for exc in climate_relevant_exchanges))
climate_labels = [exc.input['name'] for exc in climate_relevant_exchanges]
climate_cf = np.array([
    float(static_lca.characterization_matrix[static_lca.dicts.biosphere[exc.input.id], static_lca.dicts.biosphere[exc.input.id]])
    for exc in climate_relevant_exchanges
])

sobol_draws = 50000
sobol_seed = 1234
rng = np.random.default_rng(sobol_seed)
unit_cube = rng.random((sobol_draws, climate_params.shape[0]))
sampled_amounts = transform_unit_cube(climate_params, unit_cube)

direct_terms = petrol_supply * sampled_amounts * climate_cf
direct_scores = direct_terms.sum(axis=1)
total_variance = direct_scores.var(ddof=1)

sobol_table = pd.DataFrame({
    'exchange': climate_labels,
    'S1': direct_terms.var(axis=0, ddof=1) / total_variance,
}).sort_values('S1', ascending=False)
sobol_table['ST'] = sobol_table['S1']

sobol_display_table = sobol_table.copy()
sobol_display_table['S1'] = sobol_display_table['S1'].map(pretty_number)
sobol_display_table['ST'] = sobol_display_table['ST'].map(pretty_number)

print(f'Sobol seed: {sobol_seed}, draws: {sobol_draws}')
display(sobol_display_table)
print(f"Sum of first-order indices: {sobol_table['S1'].sum():.3f}")
# Out:
# Sobol seed: 1234, draws: 50000
#                      exchange         S1         ST
# 3      Carbon dioxide, fossil      0.998      0.998
# 10  1,1,1,2-Tetrafluoroethane      0.002      0.002
# 11            Methane, fossil  1.141e-07  1.141e-07
# 4         Dinitrogen monoxide  1.033e-07  1.033e-07
# 13            Methane, fossil  1.291e-08  1.291e-08
# 12            Methane, fossil  1.026e-08  1.026e-08
# 5         Dinitrogen monoxide  9.165e-09  9.165e-09
# 6         Dinitrogen monoxide  3.731e-09  3.731e-09
# 9                      Ethane  2.433e-13  2.433e-13
# 7                      Ethane  9.559e-14  9.559e-14
# 8                      Ethane  1.077e-14  1.077e-14
# 2                      Butane  1.212e-16  1.212e-16
# 0                      Butane  4.726e-17  4.726e-17
# 16                    Propane  2.430e-17  2.430e-17
# 14                    Propane  9.598e-18  9.598e-18
# 1                      Butane  5.273e-18  5.273e-18
# 15                    Propane  1.064e-18  1.064e-18
# Sum of first-order indices: 1.000

# %%
plt.figure(figsize=(8, 4))
plt.bar(sobol_table['exchange'], sobol_table['S1'], color='#54A24B')
plt.ylabel('Sobol index')
plt.title('Direct climate-score uncertainty drivers for the petrol car activity')
plt.xticks(rotation=20, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 9) Bonus: precomputed paired samples for selected exchanges
#
# Sometimes we want more control than standard Monte Carlo for a few key exchanges.
#
# Here we precompute structured pseudo-random samples for the **fuel input** of both passenger-car activities, and we derive the corresponding **fossil CO2 emission** from each sampled fuel amount. We then inject these four sample series back into Brightway with `add_persistent_array(...)`.
#
# The key point is that only these four matrix entries are overwritten. All other uncertain exchanges keep their original `brightway` / `stats_arrays` uncertainty distributions because we still run the LCA with `use_distributions=True`.

# %%
def sample_exchange_from_unit_interval(exchange, unit_interval):
    params = UncertaintyBase.from_dicts(exchange.as_dict())
    distribution = uncertainty_choices[int(params['uncertainty_type'][0])]
    return distribution.ppf(params, unit_interval.reshape(1, -1)).reshape(-1)


# we create references to the technosphere exchanges of interest
petrol_fuel_exc = next(exc for exc in petrol_car.technosphere() if 'Fuel supply' in exc.input['name'])
gas_fuel_exc = next(exc for exc in ng_car.technosphere() if 'Fuel supply' in exc.input['name'])

# same for the biosphere exchanges
petrol_co2_exc = next(exc for exc in petrol_car.biosphere() if exc.input['name'] == 'Carbon dioxide, fossil')
gas_co2_exc = next(exc for exc in ng_car.biosphere() if exc.input['name'] == 'Carbon dioxide, fossil')
petrol_ammonia_exc = next(exc for exc in petrol_car.biosphere() if exc.input['name'] == 'Ammonia')

paired_iterations = 300
paired_seed = 2026
paired_u = (np.arange(paired_iterations) + 0.5) / paired_iterations
rng = np.random.default_rng(paired_seed)
rng.shuffle(paired_u)

petrol_fuel_samples = sample_exchange_from_unit_interval(petrol_fuel_exc, paired_u)
gas_fuel_samples = sample_exchange_from_unit_interval(gas_fuel_exc, paired_u)

petrol_co2_factor = petrol_co2_exc.as_dict()['amount'] / petrol_fuel_exc.as_dict()['amount']
gas_co2_factor = gas_co2_exc.as_dict()['amount'] / gas_fuel_exc.as_dict()['amount']

petrol_co2_samples = petrol_co2_factor * petrol_fuel_samples
gas_co2_samples = gas_co2_factor * gas_fuel_samples

paired_preview = pd.DataFrame({
    'petrol fuel sample': [pretty_number(x) for x in petrol_fuel_samples[:5]],
    'petrol CO2 sample': [pretty_number(x) for x in petrol_co2_samples[:5]],
    'natural gas sample': [pretty_number(x) for x in gas_fuel_samples[:5]],
    'natural gas CO2 sample': [pretty_number(x) for x in gas_co2_samples[:5]],
})

print(f'Paired sample seed: {paired_seed}, iterations: {paired_iterations}')
display(paired_preview)
# Out:
# Paired sample seed: 2026, iterations: 300
#   petrol fuel sample petrol CO2 sample natural gas sample  \
# 0              0.048             0.144              0.059
# 1              0.047             0.143              0.059
# 2              0.049             0.147              0.061
# 3              0.047             0.144              0.059
# 4              0.049             0.148              0.061
#
#   natural gas CO2 sample
# 0                  0.144
# 1                  0.143
# 2                  0.147
# 3                  0.144
# 4                  0.148

# %%
# we create a data package for bw2calc to consume
dp_paired = bwp.create_datapackage(sequential=True)

# we add peristent arrays without our pre-computed values we want to iterate over
dp_paired.add_persistent_array(
    matrix='technosphere_matrix',
    indices_array=np.array([(petrol_fuel_exc.input.id, petrol_car.id)], dtype=bwp.INDICES_DTYPE),
    data_array=petrol_fuel_samples.reshape((1, -1)),
    flip_array=np.array([True]),
    name='petrol-fuel-override',
)
dp_paired.add_persistent_array(
    matrix='biosphere_matrix',
    indices_array=np.array([(petrol_co2_exc.input.id, petrol_car.id)], dtype=bwp.INDICES_DTYPE),
    data_array=petrol_co2_samples.reshape((1, -1)),
    name='petrol-co2-override',
)
dp_paired.add_persistent_array(
    matrix='technosphere_matrix',
    indices_array=np.array([(gas_fuel_exc.input.id, ng_car.id)], dtype=bwp.INDICES_DTYPE),
    data_array=gas_fuel_samples.reshape((1, -1)),
    flip_array=np.array([True]),
    name='gas-fuel-override',
)
dp_paired.add_persistent_array(
    matrix='biosphere_matrix',
    indices_array=np.array([(gas_co2_exc.input.id, ng_car.id)], dtype=bwp.INDICES_DTYPE),
    data_array=gas_co2_samples.reshape((1, -1)),
    name='gas-co2-override',
)

petrol_demand, petrol_data_objs, petrol_remapping = bd.prepare_lca_inputs(demand={petrol_car: 1}, method=method)
gas_demand, gas_data_objs, gas_remapping = bd.prepare_lca_inputs(demand={ng_car: 1}, method=method)

# we create our LCA objects
petrol_controlled_lca = bc.LCA(
    petrol_demand,
    data_objs=petrol_data_objs + [dp_paired],
    remapping_dicts=petrol_remapping,
    use_distributions=True,
    use_arrays=True,
)
gas_controlled_lca = bc.LCA(
    gas_demand,
    data_objs=gas_data_objs + [dp_paired],
    remapping_dicts=gas_remapping,
    use_distributions=True,
    use_arrays=True,
)
petrol_controlled_lca.lci()
petrol_controlled_lca.lcia()
gas_controlled_lca.lci()
gas_controlled_lca.lcia()
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 8.31e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.84e+12)
#   warnings.warn(msg, UmfpackWarning)

# %%
# we build a nice table to keep track of the exchange values used
petrol_fuel_row = petrol_controlled_lca.dicts.product[petrol_fuel_exc.input.id]
petrol_activity_col = petrol_controlled_lca.dicts.activity[petrol_car.id]
petrol_co2_row = petrol_controlled_lca.dicts.biosphere[petrol_co2_exc.input.id]
petrol_ammonia_row = petrol_controlled_lca.dicts.biosphere[petrol_ammonia_exc.input.id]

gas_fuel_row = gas_controlled_lca.dicts.product[gas_fuel_exc.input.id]
gas_activity_col = gas_controlled_lca.dicts.activity[ng_car.id]
gas_co2_row = gas_controlled_lca.dicts.biosphere[gas_co2_exc.input.id]

paired_records = []
for step in range(paired_iterations):
    paired_records.append({
        'iteration': step,
        'petrol fuel': -float(petrol_controlled_lca.technosphere_matrix[petrol_fuel_row, petrol_activity_col]),
        'petrol fossil CO2': float(petrol_controlled_lca.biosphere_matrix[petrol_co2_row, petrol_activity_col]),
        'petrol ammonia': float(petrol_controlled_lca.biosphere_matrix[petrol_ammonia_row, petrol_activity_col]),
        'petrol score': float(petrol_controlled_lca.score),
        'natural gas fuel': -float(gas_controlled_lca.technosphere_matrix[gas_fuel_row, gas_activity_col]),
        'natural gas fossil CO2': float(gas_controlled_lca.biosphere_matrix[gas_co2_row, gas_activity_col]),
        'natural gas score': float(gas_controlled_lca.score),
    })
    if step < paired_iterations - 1:
        next(petrol_controlled_lca)
        next(gas_controlled_lca)

paired_results = pd.DataFrame(paired_records)
paired_display = paired_results.head(6).copy()
for column in paired_display.columns[1:]:
    paired_display[column] = paired_display[column].map(pretty_number)
display(paired_display)

petrol_pairing_ok = np.allclose(
    paired_results['petrol fossil CO2'] / paired_results['petrol fuel'],
    petrol_co2_factor,
)
gas_pairing_ok = np.allclose(
    paired_results['natural gas fossil CO2'] / paired_results['natural gas fuel'],
    gas_co2_factor,
)
untouched_exchange_varies = paired_results['petrol ammonia'].nunique() > 1

print('Did the petrol fuel / CO2 pairing stay fixed?', petrol_pairing_ok)
print('Did the natural-gas fuel / CO2 pairing stay fixed?', gas_pairing_ok)
print('Did an untouched exchange still vary?', untouched_exchange_varies)
print('This means only the selected fuel and CO2 exchanges were overwritten; the other uncertain exchanges still use their original distributions.')
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.98e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.42e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 4.66e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.13e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.35e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.89e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.25e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.27e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.19e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.33e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.67e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.41e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.34e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.11e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.02e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.08e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.14e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.51e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.40e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.44e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.40e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.16e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.97e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.22e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 4.15e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 8.16e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.37e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.74e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.28e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 5.52e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 6.25e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.20e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.66e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.15e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.54e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.43e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.36e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.83e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.73e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.11e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 4.58e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.18e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.64e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 4.73e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.06e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.11e+13)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.46e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.53e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.46e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.68e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.00e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.56e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.47e+13)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.62e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.39e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.25e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 5.03e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.01e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.06e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 7.01e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.67e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.05e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.69e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 6.77e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.16e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.59e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.04e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.99e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.66e+13)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.63e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.60e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.25e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.29e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 4.47e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.78e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.30e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.45e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.10e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.82e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 5.39e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.00e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.76e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.13e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.03e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 4.25e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.08e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.71e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 4.33e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.72e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.45e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.12e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.09e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.97e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.04e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.41e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.26e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.30e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.49e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.07e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.71e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.21e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.45e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 5.07e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 5.61e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.55e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.50e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.13e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.32e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.90e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.65e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.00e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.17e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 5.24e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 8.26e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.38e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 4.63e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.31e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.66e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.11e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.29e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.27e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.50e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.23e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 8.35e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.59e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.65e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.90e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 6.95e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 5.35e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.92e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 6.56e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.41e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.88e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 6.86e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.61e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.09e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.57e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 6.30e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.36e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.01e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.96e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.07e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 7.34e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.12e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 5.48e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.77e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 4.22e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.22e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 2.52e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 5.96e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 5.17e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 7.16e+12)
#   warnings.warn(msg, UmfpackWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/lca-course/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.24e+12)
#   warnings.warn(msg, UmfpackWarning)
#    iteration petrol fuel petrol fossil CO2 petrol ammonia petrol score  \
# 0          0       0.048             0.144      1.425e-05        0.248
# 1          1       0.047             0.143      1.364e-05        0.264
# 2          2       0.049             0.147      1.387e-05        0.283
# 3          3       0.047             0.144      1.405e-05        0.265
# 4          4       0.049             0.148      1.406e-05        0.278
# 5          5        0.05             0.151      1.408e-05        0.273
#
#   natural gas fuel natural gas fossil CO2 natural gas score
# 0            0.059                  0.144             0.285
# 1            0.059                  0.143             0.298
# 2            0.061                  0.147             0.309
# 3            0.059                  0.144             0.279
# 4            0.061                  0.148             0.277
# 5            0.062                  0.151             0.296
# Did the petrol fuel / CO2 pairing stay fixed? True
# Did the natural-gas fuel / CO2 pairing stay fixed? True
# Did an untouched exchange still vary? True
# This means only the selected fuel and CO2 exchanges were overwritten; the other uncertain exchanges still use their original distributions.

# %%
paired_results
# Out:
#      iteration  petrol fuel  petrol fossil CO2  petrol ammonia  petrol score  \
# 0            0        0.048              0.144           0.000         0.248
# 1            1        0.047              0.143           0.000         0.264
# 2            2        0.049              0.147           0.000         0.283
# 3            3        0.047              0.144           0.000         0.265
# 4            4        0.049              0.148           0.000         0.278
# ..         ...          ...                ...             ...           ...
# 295        295        0.047              0.143           0.000         0.276
# 296        296        0.048              0.145           0.000         0.268
# 297        297        0.049              0.148           0.000         0.268
# 298        298        0.049              0.147           0.000         0.269
# 299        299        0.047              0.141           0.000         0.254
#
#      natural gas fuel  natural gas fossil CO2  natural gas score
# 0               0.059                   0.144              0.285
# 1               0.059                   0.143              0.298
# 2               0.061                   0.147              0.309
# 3               0.059                   0.144              0.279
# 4               0.061                   0.148              0.277
# ..                ...                     ...                ...
# 295             0.059                   0.143              0.299
# 296             0.060                   0.145              0.301
# 297             0.061                   0.148              0.285
# 298             0.061                   0.147              0.295
# 299             0.058                   0.141              0.294
#
# [300 rows x 8 columns]

# %%
plt.figure(figsize=(8, 4))
plt.hist(paired_results["petrol score"], bins=30, alpha=0.6, label='Petrol car')
plt.hist(paired_results["natural gas score"], bins=30, alpha=0.6, label='Natural gas car')
plt.xlabel('Impact score')
plt.ylabel('Frequency')
plt.title('Monte Carlo score distributions')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# We do not necessarily have a better answer than before, but we now know that the carbon balance in both transport activities is respected.

# %% [markdown]
# ## Recap
#
# After this notebook, you should now be able to:
#
# - connect Brightway uncertainty fields to the `stats_arrays` parameter-array format
# - inspect and sample uncertainty for individual exchanges
# - run stochastic LCAs in `brightway`
# - summarize score distributions with percentiles and histograms
# - explain why overlap, probability of superiority, and a statistical test should be read together
# - identify the dominant uncertainty drivers in a reduced Sobol-style analysis
# - inject precomputed samples for selected exchanges while preserving the uncertainty of the other exchanges
